# %% [markdown]
# <a href="https://colab.research.google.com/github/chsvhemanth/machinelearning/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn import preprocessing

# %%
data=pd.read_csv('/content/drive/MyDrive/Diabetes Missing Data.csv')

# %%
data
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

print("Independent Variables (X):", X.columns.tolist())
print("Dependent Variable (y):", y.name)
# Out:
# Independent Variables (X): ['Pregnant', 'Glucose', 'Diastolic_BP', 'Skin_Fold', 'Serum_Insulin', 'BMI', 'Diabetes_Pedigree', 'Age']
# Dependent Variable (y): Class

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# Ensure the dataset is in numeric format for imputation
X = data.iloc[:, :-1].values  # Extract independent variables as a NumPy array

# Create an imputer object with the mean strategy
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# Fit and transform the entire dataset to fill missing values
imputer.fit(X)  # Calculate means for columns with missing data
X = imputer.transform(X)
print("Independent Variables (after filling missing values):")
print(X)
# Out:
# Independent Variables (after filling missing values):
# [[  6.    148.     72.    ...  33.6     0.627  50.   ]
#  [  1.     85.     66.    ...  26.6     0.351  31.   ]
#  [  8.    183.     64.    ...  23.3     0.672  32.   ]
#  ...
#  [  5.    121.     72.    ...  26.2     0.245  30.   ]
#  [  1.    126.     60.    ...  30.1     0.349  47.   ]
#  [  1.     93.     70.    ...  30.4     0.315  23.   ]]

# %%
data.iloc[:, :-1] = X

# %%
data
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000     155.548223  33.6
# 1           1     85.0          66.0   29.00000     155.548223  26.6
# 2           8    183.0          64.0   29.15342     155.548223  23.3
# 3           1     89.0          66.0   23.00000      94.000000  28.1
# 4           0    137.0          40.0   35.00000     168.000000  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000     180.000000  32.9
# 764         2    122.0          70.0   27.00000     155.548223  36.8
# 765         5    121.0          72.0   23.00000     112.000000  26.2
# 766         1    126.0          60.0   29.15342     155.548223  30.1
# 767         1     93.0          70.0   31.00000     155.548223  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print("X_train (Training Features):")
print(pd.DataFrame(X_train).head())

print("\nX_test (Testing Features):")
print(pd.DataFrame(X_test).head())

print("\ny_train (Training Labels):")
print(y_train.head())

print("\ny_test (Testing Labels):")
print(y_test.head())
# Out:
# X_train (Training Features):
#       0      1     2         3           4     5      6     7
# 0   9.0  145.0  80.0  46.00000  130.000000  37.9  0.637  40.0
# 1  10.0  129.0  62.0  36.00000  155.548223  41.2  0.441  38.0
# 2   7.0  102.0  74.0  40.00000  105.000000  37.2  0.204  45.0
# 3   8.0  120.0  78.0  29.15342  155.548223  25.0  0.409  64.0
# 4   2.0  120.0  76.0  37.00000  105.000000  39.7  0.215  29.0
#
# X_test (Testing Features):
#      0      1     2         3           4     5      6     7
# 0  7.0  136.0  74.0  26.00000  135.000000  26.0  0.647  51.0
# 1  1.0  151.0  60.0  29.15342  155.548223  26.1  0.179  22.0
# 2  6.0  109.0  60.0  27.00000  155.548223  25.0  0.206  27.0
# 3  3.0   61.0  82.0  28.00000  155.548223  34.4  0.243  46.0
# 4  1.0  116.0  78.0  29.00000  180.000000  36.1  0.496  25.0
#
# y_train (Training Labels):
# 663    1
# 712    1
# 161    0
# 509    0
# 305    0
# Name: Class, dtype: int64
#
# y_test (Testing Labels):
# 285    0
# 101    0
# 581    0
# ...

# %%
# !pip install decision-tree-id3
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 4.3 MB/s eta 0:00:00
# ...
#   Created wheel for decision-tree-id3: filename=decision_tree_id3-0.1.2-py3-none-any.whl size=15939 sha256=32c729abfecac1147ea57923b4c7241895036dac090097333c94841420f40c3f
#   Stored in directory: /root/.cache/pip/wheels/b5/48/52/e8ac7a547a6343fce8e441f4db4a9052c7a8547fd91f413363
# Successfully built decision-tree-id3
# ...

# %%
import six
import sys
sys.modules ['sklearn.externals.six'] = six

# %%
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()
data ['Pregnant'] = Le.fit_transform(data['Pregnant'])
data['Glucose'] = Le.fit_transform(data['Glucose'])
data['Diastolic_BP'] = Le.fit_transform(data['Diastolic_BP'])
data['Skin_Fold'] = Le.fit_transform(data['Skin_Fold'])
data['Serum_Insulin'] = Le.fit_transform(data['Serum_Insulin'])
data['BMI'] = Le.fit_transform(data['BMI'])
data['Diabetes_Pedigree'] = Le.fit_transform(data['Diabetes_Pedigree'])
data['Age'] = Le.fit_transform(data['Age'])

# %%
y = data['Class']
x = data.drop(['Class'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.9, random_state = 0)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x_train, y_train)
clf.fit(x,y)
print(tree.export_text(clf))
# Out:
# |--- feature_1 <= 65.50
# |   |--- feature_5 <= 59.50
# |   |   |--- feature_4 <= 19.50
# |   |   |   |--- feature_6 <= 350.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_6 >  350.50
# |   |   |   |   |--- class: 1
# |   |   |--- feature_4 >  19.50
# |   |   |   |--- class: 0
# |   |--- feature_5 >  59.50
# |   |   |--- feature_7 <= 7.50
# |   |   |   |--- feature_3 <= 21.50
# |   |   |   |   |--- feature_5 <= 117.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_5 >  117.00
# |   |   |   |   |   |--- feature_5 <= 119.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_5 >  119.00
# |   |   |   |   |   |   |--- feature_4 <= 10.50
# |   |   |   |   |   |   |   |--- feature_3 <= 18.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  18.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  10.50
# |   |   |   |   |   |   |   |--- class: 0
# ...

# %%
fig, ax = plt.subplots(figsize=(100, 100))
tree.plot_tree(clf, fontsize=10)
plt.show()
